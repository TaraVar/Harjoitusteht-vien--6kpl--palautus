# %%
number1= 5
number2= 2
#print(number1)
creator = "Tara"
#print (creator)
# Out:
# 5
# Tara

# %%
print ("Printer App")
print("This app is made by: " + creator) 
print("Value of number 1 is ",number1)
print("The value of number 2 is " ,number2)
multiplication = (number1 * number2)
print(number1,"*",number2, "is =", multiplication)
addition= (number1 + number2)
print(number1, "+",number2,"is =",addition)
division=(number1/number2)
print(number1,"/",number2,"is =",division)
substraction =(number1 - number2)
print(number1, "-",number2,"is =",substraction)
# Out:
# Printer App
# This app is made by: Tara
# Value of number 1 is  5
# The value of number 2 is  2
# 5 * 2 is = 10
# 5 + 2 is = 7
# 5 / 2 is = 2.5
# 5 - 2 is = 3
