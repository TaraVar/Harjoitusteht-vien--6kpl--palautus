# %%
correctname = "Tara"

while True:
    guess = input("guess a name")
    if guess == correctname:
        print("Congratulation!")
        break 
    else:
        print("No, try again")
# Out:
# No, try again
# Congratulation!
